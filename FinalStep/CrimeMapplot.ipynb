# %% [markdown]
# # CrimeMap Plots

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("crime_final.csv")

# %%
df['CrimeMap'].unique()
# Out:
# array(['robbery', 'vandalism', 'towed', 'suspicious', 'accident',
#        'SimpleAssault', 'fire related reports', 'others', 'property',
#        'disorder', 'assembly or gathering violations', 'Vehicle',
#        'residential burglary', 'restraining order violations',
#        'violations', 'harassment', 'ballistics',
#        'police service incidents', 'drug', 'warrant', 'missing', 'fraud',
#        'AggravatedAssault', 'license plate related incidents',
#        'firearm violations', 'other burglary', 'arson', 'bomb hoax',
#        'harbor related incidents', 'counterfeiting', 'firearm discovery',
#        'service', 'operating under the influence', 'confidence games',
#        'license violation', 'commercial burglary', 'home invasion',
#        'prostitution', 'evading fare', 'prisoner related incidents',
#        'homicide', 'embezzlement', 'explosives', 'criminal harassment',
#        'phone call complaints', 'aircraft', 'biological threat',
# ...

# %%
df['CrimeMap'].value_counts()[:10].plot(kind='barh')

# %%
data=df[df['CrimeMap']=='SimpleAssault']
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('Simple Assault %f percent total'%(percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
data=df[df['CrimeMap']=='robbery']
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('Robbery %f percent total'%(percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
data=df[df['CrimeMap']=='sexual']
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('sexual %f percent total'%(percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
data=df[df['CrimeMap']=='SimpleAssault']
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('SimpleAssault %f percent total'%(percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
data=df[df['CrimeMap']=='drug']
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('Drugs %f percent total'%(percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
data=df[df['CrimeMap']=='vandalism']
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('vandalism %f percent total'%(percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='others'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='Vehicle'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='accident'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='fraud'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='trespass'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='property'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='AggravatedAssault'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='disputes'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='violations'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='prostitution'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='warrant'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='missing'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='weapon'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='harassment'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %%
parameter='gambling'
data=df[df['CrimeMap']==parameter]
data["CrimeType"].value_counts().plot(kind='barh')
percentage=len(data)/len(df)
plt.title('%s %f percent total'%(parameter,percentage*100))
plt.xlabel('Count')
plt.ylabel('CrimeType')
# Out:
# Text(0, 0.5, 'CrimeType')

# %% [markdown]
# Other CrimeMap values have very small percentages and could be eliminated!
