# %%
import pandas as pd
import numpy as np

# %%
dfBoston=pd.read_csv("crime.csv",engine='python')
dfcodes=pd.read_csv("offense_codes.csv",engine='python')

# %%
newdf=pd.DataFrame()
newdf['Date']=dfBoston['OCCURRED_ON_DATE']
newdf['District']=dfBoston['DISTRICT']
newdf["Street"]=dfBoston['STREET']
newdf['CrimeType']=dfBoston['OFFENSE_CODE_GROUP']
newdf['CrimeDetail']=dfBoston['OFFENSE_DESCRIPTION']
newdf['Long']=dfBoston['Long']
newdf["Lat"]=dfBoston["Lat"]

# %%
newdf
# Out:
#                        Date District             Street             CrimeType  \
# 0       2018-09-02 13:00:00      D14         LINCOLN ST               Larceny
# 1       2018-08-21 00:00:00      C11           HECLA ST             Vandalism
# 2       2018-09-03 19:27:00       D4        CAZENOVE ST                 Towed
# 3       2018-09-03 21:16:00       D4         NEWCOMB ST  Investigate Property
# 4       2018-09-03 21:05:00       B3           DELHI ST  Investigate Property
# ...                     ...      ...                ...                   ...
# 319068  2016-06-05 17:25:00       D4        COVENTRY ST       Warrant Arrests
# 319069  2015-07-09 13:38:00      E18           RIVER ST              Homicide
# 319070  2015-07-09 13:38:00      E18           RIVER ST       Warrant Arrests
# 319071  2016-05-31 19:35:00      E13  NEW WASHINGTON ST       Warrant Arrests
# 319072  2015-06-22 00:12:00       D4      WASHINGTON ST       Warrant Arrests
#
# ...

# %%
newdf.to_csv("BostonCrimeF.csv")
