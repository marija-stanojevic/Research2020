# %%
import pandas as pd

# %%
df=pd.read_csv("news_full.csv")

# %%
finalString=''
for i in df['Content']:
    finalString=finalString+" "+i+"/"

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import numpy as np

import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(finalString)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# lower max_font_size, change the maximum number of word and lighten the background:
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(finalString)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
df.iloc[700]["Common_Ent.append"]
# Out:
# "[('San Bernardino', 64), ('61', 62), ('SAN BERNARDINO', 33), ('AP', 27), ('14', 25), ('California', 18), ('San Bernardino California', 14), ('Farook', 12), ('Calif.', 12), ('FBI', 10), ('Dec. 3', 10), ('Tashfeen Malik', 9), ('two', 8), ('Dec. 2', 8), ('Syed Farook', 7), ('the Inland Regional Center', 6), ('Friday', 6), ('Wednesday', 6), ('Southern California', 6), ('28500', 5), ('Obama', 5), ('Wednesdays', 5), ('Tuesday', 4), ('Syed Rizwan Farook', 4), ('21', 4), ('Dec. 7', 4), ('12', 4), ('last week', 3), ('87', 3), ('1', 3)]"
